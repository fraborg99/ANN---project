# %%
import numpy as np

# %%
M_list = ['rand', 'opt']
e_list = [0,0.05, 0.1, 0.25, 0.5, 0.75, 1]

even_dict = {'X': -1, 'O': 1, None: 0}
odd_dict  = {'X': 1, 'O': -1, None: 0}

M_rand = []
M_opt = []
M = [M_rand, M_opt]
for m in range(2):
    for e in e_list:
        file_name = 'Q4_' + M_list[m] + '_n' + str(e)
        file_path = "Q4/" + file_name + ".npy"
        
        print(file_name)
        
        rewards = np.load(file_path, allow_pickle = True)
        rewards[:,:,::2]  = np.vectorize(even_dict.__getitem__)(rewards[:,:,::2])
        rewards[:,:,1::2] = np.vectorize(odd_dict.__getitem__)(rewards[:,:,1::2])
        
        M[m].append(rewards.mean(axis=2).mean(axis=0))
# Out:
# Q4_rand_n0
# Q4_rand_n0.05
# Q4_rand_n0.1
# Q4_rand_n0.25
# Q4_rand_n0.5
# Q4_rand_n0.75
# Q4_rand_n1
# Q4_opt_n0
# Q4_opt_n0.05
# Q4_opt_n0.1
# Q4_opt_n0.25
# Q4_opt_n0.5
# Q4_opt_n0.75
# Q4_opt_n1

# %%
import matplotlib.pyplot as plt
 
palette_opt = plt.get_cmap('YlOrRd')
palette_rand = plt.get_cmap('Blues')

 
    

for i in range(len(M_opt)):
    plt.plot(np.arange(80), M_opt[i], color=palette_opt(i*30 + 50), label='$M_{opt}$ ' + f'n* = {e_list[i]}')

for i in range(len(M_rand)):
    plt.plot(np.arange(80), M_rand[i], color=palette_rand(i*30 + 50), label='$M_{rand}$ ' + f'n* = {e_list[i]}')

# Add legend
plt.legend(loc=4, ncol=2)
 
# Add titles
plt.title("MODIFICARE", loc='left', fontsize=12, fontweight=0)
plt.xlabel("MODIFICARE")

plt.rcParams["figure.figsize"] = (20,12)

# Show the graph
plt.show()
